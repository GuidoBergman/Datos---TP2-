# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def graficarPorcentajes(pesos, titulos):
    dic = {}
    for i in range(len(titulos)):
        porcentajes_pesos = []
        for j in range(len(pesos[i])):
            porcentajes_pesos.append(pesos[i][j]/sum(pesos[i])*100)
        
        dic[titulos[i]] = porcentajes_pesos
        
    df_pesos = pd.DataFrame(dic).T
    df_pesos.columns=['XBoost basado en Benchmark', 'XGBoost basado en KNN', 'Catboost', 'KNN']

    g = df_pesos.plot(kind='bar', stacked=False, rot=0, figsize=(10,6))
    g.grid(axis='y')
    
    g.set_title('Porcentaje del peso asignado a cada modelo\n según su Score',
               fontsize=20)
    g.set_ylabel('Porcentaje del peso(%)', fontsize=16)
    plt.legend(loc='lower center')

# %%
graficarPorcentajes([[4,3,2,1],[4,3,2,0]], ["Ranking", "Ranking sin KNN"])

# %%
graficarPorcentajes([[469,460,395, 348],[469,460,395, 145.64]], ['Score','Score reduciendo KNN'])

# %%
def graficarPorcentajes1(pesos, titulos):
    dic = {}
    for i in range(len(titulos)):
        porcentajes_pesos = []
        for j in range(len(pesos[i])):
            porcentajes_pesos.append(pesos[i][j]/sum(pesos[i])*100)
        
        dic[titulos[i]] = porcentajes_pesos
        
    df_pesos = pd.DataFrame(dic).T
    df_pesos.columns=['XBoost basado en Benchmark', 'XGBoost basado en KNN', 'LightGBM','Catboost']

    g = df_pesos.plot(kind='bar', stacked=False, rot=0, figsize=(10,6))
    g.grid(axis='y')
    
    g.set_title('Porcentaje del peso asignado a cada modelo\n buscando mediante optimizacion bayesiana',
               fontsize=20)
    g.set_ylabel('Porcentaje del peso(%)', fontsize=16)
    plt.legend(loc='best')
    plt.xticks(size=12)

# %%
graficarPorcentajes1([[3.353088965342895,4.237636212714062,1.3465747679887474,1.0052309329869793],
                      [4.219716801624352,3.411887326897567,2.39216802199134,1]], 
                     ["Labels", "Probabilidades"])

# %%
Sin probas
{'peso_baseline': ,
  'peso_catboost': ,
  'peso_lgbm': ,
  'peso_short1': }

# %%
 Peso baseline: 
	 Peso short1: 
	 Peso lgbm: 
        catboost 1
